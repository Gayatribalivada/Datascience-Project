# %%
import yfinance as yf
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **Apple Inc. (AAPL)**

# %%
aapl_stock = yf.download("AAPL", start="2013-01-01", end="2025-05-30", auto_adjust=False)['Adj Close']
aapl_stock
# Out:
# [*********************100%***********************]  1 of 1 completed
# Ticker            AAPL
# Date
# 2013-01-02   16.647184
# 2013-01-03   16.437067
# 2013-01-04   15.979206
# 2013-01-07   15.885213
# 2013-01-08   15.927969
# ...                ...
# 2025-05-22  201.360001
# 2025-05-23  195.270004
# 2025-05-27  200.210007
# 2025-05-28  200.419998
# 2025-05-29  199.949997
#
# [3121 rows x 1 columns]

# %%
aapl_stock = aapl_stock.reset_index()  # Move Date from index to column
aapl_stock.columns = ['Date', 'Adj Close']  # Renaming columns
aapl_stock['Stock Name'] = 'Apple'
aapl_stock
# Out:
#            Date   Adj Close Stock Name
# 0    2013-01-02   16.647184      Apple
# 1    2013-01-03   16.437067      Apple
# 2    2013-01-04   15.979206      Apple
# 3    2013-01-07   15.885213      Apple
# 4    2013-01-08   15.927969      Apple
# ...         ...         ...        ...
# 3116 2025-05-22  201.360001      Apple
# 3117 2025-05-23  195.270004      Apple
# 3118 2025-05-27  200.210007      Apple
# 3119 2025-05-28  200.419998      Apple
# 3120 2025-05-29  199.949997      Apple
#
# [3121 rows x 3 columns]

# %%
import os
os.makedirs('/Stocks Data', exist_ok=True)
aapl_stock.to_csv('/Stocks Data/Apple_stock.csv', index=False)

# %% [markdown]
# # **Microsoft Corporation (MSFT)**

# %%
msft_stock = yf.download("MSFT", start="2013-01-01", end="2025-05-30", auto_adjust=False)['Adj Close']
msft_stock = msft_stock.reset_index()  # Move Date from index to column
msft_stock.columns = ['Date', 'Adj Close']  # Renaming columns
msft_stock['Stock Name'] = 'MSFT'
msft_stock
# Out:
# [*********************100%***********************]  1 of 1 completed
#            Date   Adj Close Stock Name
# 0    2013-01-02   22.321148       MSFT
# 1    2013-01-03   22.022125       MSFT
# 2    2013-01-04   21.609970       MSFT
# 3    2013-01-07   21.569563       MSFT
# 4    2013-01-08   21.456421       MSFT
# ...         ...         ...        ...
# 3116 2025-05-22  454.859985       MSFT
# 3117 2025-05-23  450.179993       MSFT
# 3118 2025-05-27  460.690002       MSFT
# 3119 2025-05-28  457.359985       MSFT
# 3120 2025-05-29  458.679993       MSFT
#
# [3121 rows x 3 columns]

# %%
msft_stock.to_csv('/Stocks Data/Microsoft_stock.csv', index=False)

# %% [markdown]
# # **Alphabet Inc. (GOOGL)**

# %%
googl_stock = yf.download("GOOGL", start="2013-01-01", end="2025-05-30", auto_adjust=False)['Adj Close']
googl_stock = googl_stock.reset_index()  # Move Date from index to column
googl_stock.columns = ['Date', 'Adj Close']  # Renaming columns
googl_stock['Stock Name'] = 'Google'
googl_stock
# Out:
# [*********************100%***********************]  1 of 1 completed
#            Date   Adj Close Stock Name
# 0    2013-01-02   17.991447     Google
# 1    2013-01-03   18.001894     Google
# 2    2013-01-04   18.357618     Google
# 3    2013-01-07   18.277519     Google
# 4    2013-01-08   18.241451     Google
# ...         ...         ...        ...
# 3116 2025-05-22  170.663391     Google
# 3117 2025-05-23  168.266296     Google
# 3118 2025-05-27  172.690933     Google
# 3119 2025-05-28  172.151596     Google
# 3120 2025-05-29  171.652191     Google
#
# [3121 rows x 3 columns]

# %%
googl_stock.to_csv('/Stocks Data/ALPHABET_stock.csv', index=False)

# %% [markdown]
# # **Exxon Mobil Corporation (XOM)**

# %%
xom_stock = yf.download("XOM", start="2013-01-01", end="2025-05-30", auto_adjust=False)['Adj Close']
xom_stock = xom_stock.reset_index()  # Move Date from index to column
xom_stock.columns = ['Date', 'Adj Close']  # Renaming columns
xom_stock['Stock Name'] = 'XOM'
xom_stock
# Out:
# [*********************100%***********************]  1 of 1 completed
#            Date   Adj Close Stock Name
# 0    2013-01-02   53.340290        XOM
# 1    2013-01-03   53.244072        XOM
# 2    2013-01-04   53.490566        XOM
# 3    2013-01-07   52.871265        XOM
# 4    2013-01-08   53.201988        XOM
# ...         ...         ...        ...
# 3116 2025-05-22  102.970001        XOM
# 3117 2025-05-23  103.029999        XOM
# 3118 2025-05-27  103.519997        XOM
# 3119 2025-05-28  102.110001        XOM
# 3120 2025-05-29  102.690002        XOM
#
# [3121 rows x 3 columns]

# %%
xom_stock.to_csv('/Stocks Data/EXXON_stock.csv', index=False)

# %% [markdown]
# # **Diamondback Energy, Inc. (FANG)**

# %%
fang_stock = yf.download("FANG", start="2013-01-01", end="2025-05-30", auto_adjust=False)['Adj Close']
fang_stock = fang_stock.reset_index()  # Move Date from index to column
fang_stock.columns = ['Date', 'Adj Close']  # Renaming columns
fang_stock['Stock Name'] = 'FANG'
fang_stock
# Out:
# [*********************100%***********************]  1 of 1 completed
#            Date   Adj Close Stock Name
# 0    2013-01-02   15.088324       FANG
# 1    2013-01-03   15.009899       FANG
# 2    2013-01-04   15.723538       FANG
# 3    2013-01-07   16.288177       FANG
# 4    2013-01-08   16.154860       FANG
# ...         ...         ...        ...
# 3116 2025-05-22  136.289993       FANG
# 3117 2025-05-23  135.860001       FANG
# 3118 2025-05-27  137.490005       FANG
# 3119 2025-05-28  136.279999       FANG
# 3120 2025-05-29  137.809998       FANG
#
# [3121 rows x 3 columns]

# %%
fang_stock.to_csv('/Stocks Data/Diamondback_stock.csv', index=False)

# %% [markdown]
# # **Walmart Inc. (WMT)**

# %%
wmt_stock = yf.download("WMT", start="2013-01-01", end="2025-05-30", auto_adjust=False)['Adj Close']
wmt_stock = wmt_stock.reset_index()  # Move Date from index to column
wmt_stock.columns = ['Date', 'Adj Close']  # Renaming columns
wmt_stock['Stock Name'] = 'WMT'
wmt_stock
# Out:
# [*********************100%***********************]  1 of 1 completed
#            Date  Adj Close Stock Name
# 0    2013-01-02  17.898834        WMT
# 1    2013-01-03  17.785093        WMT
# 2    2013-01-04  17.852306        WMT
# 3    2013-01-07  17.681692        WMT
# 4    2013-01-08  17.730808        WMT
# ...         ...        ...        ...
# 3116 2025-05-22  95.930000        WMT
# 3117 2025-05-23  96.339996        WMT
# 3118 2025-05-27  97.580002        WMT
# 3119 2025-05-28  97.239998        WMT
# 3120 2025-05-29  97.099998        WMT
#
# [3121 rows x 3 columns]

# %%
wmt_stock.to_csv('/Stocks Data/Walmart_stock.csv', index=False)

# %% [markdown]
# # **Dollar General Corporation (DG)**

# %%
dg_stock = yf.download("DG", start="2013-01-01", end="2025-05-30", auto_adjust=False)['Adj Close']
dg_stock = dg_stock.reset_index()  # Move Date from index to column
dg_stock.columns = ['Date', 'Adj Close']  # Renaming columns
dg_stock['Stock Name'] = 'DG'
dg_stock
# Out:
# [*********************100%***********************]  1 of 1 completed
#            Date   Adj Close Stock Name
# 0    2013-01-02   37.745232         DG
# 1    2013-01-03   37.226372         DG
# 2    2013-01-04   39.222687         DG
# 3    2013-01-07   38.448795         DG
# 4    2013-01-08   38.132195         DG
# ...         ...         ...        ...
# 3116 2025-05-22  100.639999         DG
# 3117 2025-05-23  101.389999         DG
# 3118 2025-05-27  100.980003         DG
# 3119 2025-05-28   97.769997         DG
# 3120 2025-05-29   97.070000         DG
#
# [3121 rows x 3 columns]

# %%
dg_stock.to_csv('/Stocks Data/DG_stock.csv', index=False)

# %% [markdown]
# # **Johnson & Johnson (JNJ)**

# %%
jnj_stock = yf.download("JNJ", start="2013-01-01", end="2025-05-30", auto_adjust=False)['Adj Close']
jnj_stock = jnj_stock.reset_index()  # Move Date from index to column
jnj_stock.columns = ['Date', 'Adj Close']  # Renaming columns
jnj_stock['Stock Name'] = 'JNJ'
jnj_stock
# Out:
# [*********************100%***********************]  1 of 1 completed
#            Date   Adj Close Stock Name
# 0    2013-01-02   49.931335        JNJ
# 1    2013-01-03   49.860855        JNJ
# 2    2013-01-04   50.431774        JNJ
# 3    2013-01-07   50.326050        JNJ
# 4    2013-01-08   50.333111        JNJ
# ...         ...         ...        ...
# 3116 2025-05-22  151.312805        JNJ
# 3117 2025-05-23  151.639999        JNJ
# 3118 2025-05-27  153.250000        JNJ
# 3119 2025-05-28  152.429993        JNJ
# 3120 2025-05-29  153.580002        JNJ
#
# [3121 rows x 3 columns]

# %%
jnj_stock.to_csv('/Stocks Data/Johnson&Johnson_stock.csv', index=False)

# %% [markdown]
# # **JPMorgan Chase & Co. (JPM)**

# %%
jpm_stock = yf.download("JPM", start="2013-01-01", end="2025-05-30", auto_adjust=False)['Adj Close']
jpm_stock = jpm_stock.reset_index()  # Move Date from index to column
jpm_stock.columns = ['Date', 'Adj Close']  # Renaming columns
jpm_stock['Stock Name'] = 'JPM'
jpm_stock
# Out:
# [*********************100%***********************]  1 of 1 completed
#            Date   Adj Close Stock Name
# 0    2013-01-02   31.950426        JPM
# 1    2013-01-03   31.886034        JPM
# 2    2013-01-04   32.451206        JPM
# 3    2013-01-07   32.486980        JPM
# 4    2013-01-08   32.551376        JPM
# ...         ...         ...        ...
# 3116 2025-05-22  260.670013        JPM
# 3117 2025-05-23  260.709991        JPM
# 3118 2025-05-27  265.290009        JPM
# 3119 2025-05-28  263.489990        JPM
# 3120 2025-05-29  264.369995        JPM
#
# [3121 rows x 3 columns]

# %%
jpm_stock.to_csv('/Stocks Data/JPMorgan_stock.csv', index=False)

# %% [markdown]
# # **Citizens Financial Group, Inc. (CFG)**

# %%
cfg_stock = yf.download("CFG", start="2013-01-01", end="2025-05-30", auto_adjust=False)['Adj Close']
cfg_stock = cfg_stock.reset_index()  # Move Date from index to column
cfg_stock.columns = ['Date', 'Adj Close']  # Renaming columns
cfg_stock['Stock Name'] = 'CFG'
print(cfg_stock.head())
cfg_stock
# Out:
# [*********************100%***********************]  1 of 1 completed
#         Date  Adj Close Stock Name
# 0 2014-09-24  15.905584        CFG
# 1 2014-09-25  15.884916        CFG
# 2 2014-09-26  16.022741        CFG
# 3 2014-09-29  16.008957        CFG
# 4 2014-09-30  16.139893        CFG
#            Date  Adj Close Stock Name
# 0    2014-09-24  15.905584        CFG
# 1    2014-09-25  15.884916        CFG
# 2    2014-09-26  16.022741        CFG
# 3    2014-09-29  16.008957        CFG
# 4    2014-09-30  16.139893        CFG
# ...         ...        ...        ...
# 2681 2025-05-22  39.770000        CFG
# 2682 2025-05-23  39.570000        CFG
# 2683 2025-05-27  40.419998        CFG
# 2684 2025-05-28  39.730000        CFG
# 2685 2025-05-29  40.259998        CFG
#
# [2686 rows x 3 columns]

# %%
cfg_stock.to_csv('/Stocks Data/CitizensFinancialGroup_stock.csv', index=False)

# %%
three_months_stock = yf.download("AAPL", start="2025-01-01", end="2025-03-31", auto_adjust=False)['Adj Close']
three_months_stock = three_months_stock.reset_index()  # Move Date from index to column
three_months_stock.columns = ['Date', 'Adj Close']  # Renaming columns
three_months_stock['Stock Name'] = 'Apple3'
three_months_stock.to_csv('/Stocks Data/Apple3Months_Stock.csv', index=False)
three_months_stock
# Out:
# [*********************100%***********************]  1 of 1 completed
#          Date   Adj Close Stock Name
# 0  2025-01-02  243.263199     Apple3
# 1  2025-01-03  242.774368     Apple3
# 2  2025-01-06  244.410416     Apple3
# 3  2025-01-07  241.627136     Apple3
# 4  2025-01-08  242.115952     Apple3
# 5  2025-01-10  236.280045     Apple3
# 6  2025-01-13  233.835922     Apple3
# 7  2025-01-14  232.718613     Apple3
# 8  2025-01-15  237.297562     Apple3
# 9  2025-01-16  227.710693     Apple3
# 10 2025-01-17  229.426559     Apple3
# 11 2025-01-21  222.104218     Apple3
# 12 2025-01-22  223.291367     Apple3
# 13 2025-01-23  223.121780     Apple3
# 14 2025-01-24  222.243881     Apple3
# 15 2025-01-27  229.306854     Apple3
# 16 2025-01-28  237.686630     Apple3
# 17 2025-01-29  238.783981     Apple3
# 18 2025-01-30  237.018234     Apple3
# 19 2025-01-31  235.432083     Apple3
# 20 2025-02-03  227.461288     Apple3
# 21 2025-02-04  232.239777     Apple3
# 22 2025-02-05  231.910583     Apple3
# 23 2025-02-06  232.658768     Apple3
# 24 2025-02-07  227.082214     Apple3
# 25 2025-02-10  227.351852     Apple3
# 26 2025-02-11  232.315353     Apple3
# 27 2025-02-12  236.559784     Apple3
# 28 2025-02-13  241.213684     Apple3
# 29 2025-02-14  244.279663     Apple3
# 30 2025-02-18  244.149841     Apple3
# 31 2025-02-19  244.549301     Apple3
# 32 2025-02-20  245.508057     Apple3
# 33 2025-02-21  245.228424     Apple3
# 34 2025-02-24  246.776398     Apple3
# 35 2025-02-25  246.716461     Apple3
# 36 2025-02-26  240.045212     Apple3
# 37 2025-02-27  236.989227     Apple3
# 38 2025-02-28  241.523270     Apple3
# 39 2025-03-03  237.718262     Apple3
# 40 2025-03-04  235.621017     Apple3
# 41 2025-03-05  235.431274     Apple3
# 42 2025-03-06  235.021805     Apple3
# 43 2025-03-07  238.756912     Apple3
# 44 2025-03-10  227.182083     Apple3
# 45 2025-03-11  220.550781     Apple3
# 46 2025-03-12  216.695831     Apple3
# 47 2025-03-13  209.405396     Apple3
# 48 2025-03-14  213.210419     Apple3
# 49 2025-03-17  213.719742     Apple3
# 50 2025-03-18  212.411453     Apple3
# 51 2025-03-19  214.958115     Apple3
# 52 2025-03-20  213.819611     Apple3
# 53 2025-03-21  217.984146     Apple3
# 54 2025-03-24  220.440918     Apple3
# 55 2025-03-25  223.456970     Apple3
# 56 2025-03-26  221.239868     Apple3
# 57 2025-03-27  223.556839     Apple3
# 58 2025-03-28  217.614624     Apple3
